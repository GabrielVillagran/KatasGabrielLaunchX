# %% [markdown]
# #Evidencia de la kata 2 (Creación de paquetes y entorno virtual)
# Comandos usados para la creación del entorno virtual
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Nota: Para ejecutar “env\Scripts\activate” fue necesario dar permisos utilizando el comando “get-executionpolicy”
#
# Ejecuta el comando pip freeze para ver las bibliotecas instaladas en tu
# entorno: (No se obtuvo respuesta como debería de suceder)
#
# Ejecuta el comando pip install para instalar una biblioteca:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Vuelve a ejecutar pip freeze para ver cómo ha cambiado tu lista de
# bibliotecas:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Links utilizados
# - How to Enable PowerShell Scripts Execution on Windows 10
# (windowsloop.com)
# - Tutorial - Instalación del entorno virtual de Python en Windows [ Paso a
# paso ] (techexpert.tips)
